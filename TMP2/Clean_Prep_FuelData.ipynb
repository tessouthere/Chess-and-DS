# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('alt_fuel_stations.csv')
# Out:
# /var/folders/bn/mdffb48j50d5vh0gf4cs_6v00000gn/T/ipykernel_51924/3656789621.py:1: DtypeWarning: Columns (3,6,10,13,14,15,16,20,29,31,33,34,35,36,43,45,46,47,49,52,53,54,56,57,58,59,60,61,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('alt_fuel_stations.csv')

# %%
df.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0            CNG               Spire - Montgomery Operations Center
# 1            CNG                                PS Energy - Atlanta
# 2            CNG       Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                              United Parcel Service
# 4            CNG  Clean Energy - Texas Department of Transportation
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# 3  270 Marvin Miller Dr                                                NaN
# 4   7721A Washington St  I-10, Washington Ave exit, 1.5 blocks to the s...
#
#          City State    ZIP  Plus4 Station Phone Status Code  ...  \
# ...

# %%
def get_region(state, region):
    if state in region['WEST']:
        return 'WEST'
    elif state in region['SOUTHEAST']:
        return 'SOUTHEAST'
    elif state in region['MIDWEST']:
        return 'MIDWEST'
    elif state in region['SOUTHWEST']:
        return 'SOUTHWEST'
    elif state in region['NORTHEAST']:
        return 'NORTHEAST'
    else:
        return None

WEST = ['WA', "OR", "ID", "MT","WY","NV","CA","UT","CO","AK","HI"]
SOUTHEAST =  ["MD","DE","DC","WV",'VA',"KY","TN","NC","SC","GA",'FL',"AL","MS","LA","AR","PR"]
MIDWEST = ["ND","MN","WI","MI","SD","IA","NE","IL","IN","OH","MO","KS"]
SOUTHWEST = ['AZ', 'NM','OK', 'TX']
NORTHEAST = ["ME","VT","NH","MA","RI","CT","NJ","PA","NY"]

region = {'WEST': WEST, 'SOUTHEAST': SOUTHEAST, 'MIDWEST': MIDWEST, 'SOUTHWEST': SOUTHWEST, 'NORTHEAST': NORTHEAST}
df['Region'] = df['State'].apply(get_region, args=(region,))
df.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0            CNG               Spire - Montgomery Operations Center
# 1            CNG                                PS Energy - Atlanta
# 2            CNG       Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                              United Parcel Service
# 4            CNG  Clean Energy - Texas Department of Transportation
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# 3  270 Marvin Miller Dr                                                NaN
# 4   7721A Washington St  I-10, Washington Ave exit, 1.5 blocks to the s...
#
#          City State    ZIP  Plus4 Station Phone Status Code  ...  \
# ...

# %%
df.to_csv('fuel_stations.csv', index=False)
